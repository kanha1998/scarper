# %%
import beatifulscout
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fcf2f62ac071> in <module>()
# ----> 1 import beutifulscout
#
# ModuleNotFoundError: No module named 'beutifulscout'

# %%
import urllib2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-846c1dbd158b> in <module>()
# ----> 1 import urllib2
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
import scarpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-ced58001a0e7> in <module>()
# ----> 1 import scarpy
#
# ModuleNotFoundError: No module named 'scarpy'

# %%
from bs4 import BeautifulSoup

# %%
import urllib2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-846c1dbd158b> in <module>()
# ----> 1 import urllib2
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
import request
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-e392607f0c42> in <module>()
# ----> 1 import request
#
# ModuleNotFoundError: No module named 'request'

# %%
import requests

# %%
page = requests.get("https://www.crunchbase.com/search/organization.companies")

# %%
page
# Out:
# <Response [416]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html>\n\n<head>\n  <title>Pardon Our Interruption</title>\n  <link rel="stylesheet" type="text/css" href="//cdn.distilnetworks.com/css/distil.css" media="all">\n  <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n  <meta name="viewport" content="width=1000" />\n  <META NAME="robots" CONTENT="noindex, nofollow">\n  <meta http-equiv="cache-control" content="max-age=0" />\n  <meta http-equiv="cache-control" content="no-cache" />\n  <meta http-equiv="expires" content="0" />\n  <meta http-equiv="expires" content="Tue, 01 Jan 1980 1:00:00 GMT" />\n  <meta http-equiv="pragma" content="no-cache" />\n</head>\n\n<body class=\'block-page\'>\n  <div class=\'container\'>\n    <div class=\'row\'>\n      <div class=\'sidebar col-lg-4 col-sm-5\'>\n        <img src="//cdn.distilnetworks.com/images/anomaly-detected.png" alt="0">\n      </div>\n      <div class=\'content col-lg-8 col-sm-7\'>\n        <h1>Pardon Our Interruption...</h1>\n        <p>\n          As
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# soup

# %%
list(soup.children)
# Out:
# ['html', '\n', <html>
#  <head>
#  <title>Pardon Our Interruption</title>
#  <link href="//cdn.distilnetworks.com/css/distil.css" media="all" rel="stylesheet" type="text/css"/>
#  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#  <meta content="width=1000" name="viewport"/>
#  <meta content="noindex, nofollow" name="robots"/>
#  <meta content="max-age=0" http-equiv="cache-control">
#  <meta content="no-cache" http-equiv="cache-control"/>
#  <meta content="0" http-equiv="expires"/>
#  <meta content="Tue, 01 Jan 1980 1:00:00 GMT" http-equiv="expires"/>
#  <meta content="no-cache" http-equiv="pragma"/>
#  </meta></head>
#  <body class="block-page">
#  <div class="container">
#  <div class="row">
#  <div class="sidebar col-lg-4 col-sm-5">
#  <img alt="0" src="//cdn.distilnetworks.com/images/anomaly-detected.png"/>
#  </div>
#  <div class="content col-lg-8 col-sm-7">
#  <h1>Pardon Our Interruption...</h1>
#  <p>
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[2]

# %%
html
# Out:
# <html>
# <head>
# <title>Pardon Our Interruption</title>
# <link href="//cdn.distilnetworks.com/css/distil.css" media="all" rel="stylesheet" type="text/css"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=1000" name="viewport"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="max-age=0" http-equiv="cache-control">
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="0" http-equiv="expires"/>
# <meta content="Tue, 01 Jan 1980 1:00:00 GMT" http-equiv="expires"/>
# <meta content="no-cache" http-equiv="pragma"/>
# </meta></head>
# <body class="block-page">
# <div class="container">
# <div class="row">
# <div class="sidebar col-lg-4 col-sm-5">
# <img alt="0" src="//cdn.distilnetworks.com/images/anomaly-detected.png"/>
# </div>
# <div class="content col-lg-8 col-sm-7">
# <h1>Pardon Our Interruption...</h1>
# <p>
# ...

# %%
list(html.children)
# Out:
# ['\n', <head>
#  <title>Pardon Our Interruption</title>
#  <link href="//cdn.distilnetworks.com/css/distil.css" media="all" rel="stylesheet" type="text/css"/>
#  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#  <meta content="width=1000" name="viewport"/>
#  <meta content="noindex, nofollow" name="robots"/>
#  <meta content="max-age=0" http-equiv="cache-control">
#  <meta content="no-cache" http-equiv="cache-control"/>
#  <meta content="0" http-equiv="expires"/>
#  <meta content="Tue, 01 Jan 1980 1:00:00 GMT" http-equiv="expires"/>
#  <meta content="no-cache" http-equiv="pragma"/>
#  </meta></head>, '\n', <body class="block-page">
#  <div class="container">
#  <div class="row">
#  <div class="sidebar col-lg-4 col-sm-5">
#  <img alt="0" src="//cdn.distilnetworks.com/images/anomaly-detected.png"/>
#  </div>
#  <div class="content col-lg-8 col-sm-7">
#  <h1>Pardon Our Interruption...</h1>
#  <p>
# ...

# %%
test=soup.find(id="mat-list-item-content")

# %%
print(test)
# Out:
# None

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
test=soup.find(id="mat-list-item ng-star-inserted mat-list-item-focus")

# %%
print (test)
# Out:
# None

# %%
for link in soup.findAll('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# http://ds.tl/help-third-party-plugins

# %%
for link in soup.find('title'):
    print(link)
# Out:
# Pardon Our Interruption

# %%
companies = soup.select(.component--field-formatter field-type-identifier-multi)
# Out:
#   File "<ipython-input-30-4d123043ec44>", line 1
#     companies = soup.select(.component--field-formatter field-type-identifier-multi)
#                             ^
# SyntaxError: invalid syntax

# %%
print(companies)
# Out:
# []

# %%
from urllib import urlopen
from bs4 import BeautifulSoup

html = urlopen('http://www.pythonscraping.com/pages/page3.html')
soup = BeautifulSoup(html)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-679f49706fb6> in <module>()
# ----> 1 from urllib import urlopen
#       2 from bs4 import BeautifulSoup
#       3
#       4 html = urlopen('http://www.pythonscraping.com/pages/page3.html')
#       5 soup = BeautifulSoup(html)
#
# ImportError: cannot import name 'urlopen'

# %%
import requests
from bs4 import BeautifulSoup

html = requests.get('http://www.pythonscraping.com/pages/page3.html')
soup = BeautifulSoup(html.content,'lxml')

# %%
for child in soup.find("table",id="giftList").tr.next_siblings:
    print(child)
# Out:
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# ...

# %%
import re

# %%
import requests
from bs4 import BeautifulSoup

html = requests.get('https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_population')

# %%
html
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(html.content,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of states and union territories of India by population - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
for content in soup.findAll("div",{"class":"toc"}):
    print(content.get_text())
# Out:
# Contents
#
# 1 Census of India
# 2 States and union territories (by population)
# 3 Notes
# 4 See also
# 5 References
# 6 External links

# %%
for link in soup.findAll("a"):
    if "href" in link.attrs:
        print(link.attrs["href"])
# Out:
# /wiki/Wikipedia:Featured_lists
# #mw-head
# #p-search
# /wiki/States_and_union_territories_of_India
# /wiki/File:Flag_of_India.svg
# /wiki/List_of_states_and_union_territories_of_India_by_area
# /wiki/ISO_3166-2:IN
# /wiki/List_of_state_and_union_territory_capitals_in_India
# /wiki/List_of_Indian_states_by_Child_Nutrition
# /wiki/Indian_states_and_territories_ranking_by_crime_rate
# /wiki/Indian_states_ranking_by_households_having_electricity
# /wiki/Indian_states_ranking_by_fertility_rate
# /wiki/Forest_cover_by_state_in_India
# /wiki/List_of_Indian_states_and_union_territories_by_GDP
# /wiki/List_of_Indian_states_by_GDP_per_capita
# /wiki/List_of_Indian_states_and_territories_by_highest_point
# /wiki/Indian_states_ranked_by_HIV_awareness
# /wiki/List_of_Indian_states_and_territories_by_Human_Development_Index
# /wiki/Indian_states_ranking_by_families_owning_house
# /wiki/Indian_states_ranking_by_household_size
# ...

# %%
for table in soup.findAll("table",{"class":"wikitable sortable jquery-tablesorter"}):
    print(table.get_text())

# %%
import requests
from bs4 import BeautifulSoup

html = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/test')
soup = BeautifulSoup(html.content,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Test Match Team Rankings International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Test Match Team Rankings International Cricket Council" property="og:title"/>
# ...

# %%
for currency in soup.findAll(class_="clearfix tbl_boxcrypto PR"):
    print(currency)
# Out:
# <div class="clearfix tbl_boxcrypto PR">
# <div class="name_overlay"></div>
# <span id="tradingview-copyright">
# <a href="http://in.tradingview.com" ref="nofollow noopener" style='color: rgb(173, 174, 176); font-family: "Trebuchet MS", Tahoma, Arial, sans-serif; font-size: 13px;' target="_blank">Cryptocurrency Market by <span style="color: #3BB3E4">TradingView</span></a>
# </span>
# <script src="https://s3.tradingview.com/external-embedding/embed-widget-screener.js">{
# 				"width": "100%",
# 				"height": "100%",
# 				"defaultColumn": "overview",
# 				"screener_type": "crypto_mkt",
# 				"displayCurrency": "USD",
# 				"locale": "in",
# 				"customer": "moneycontrol",
# 				"whitelabel": 1
# 				}
# 			</script>
# </div>

# %%
for cricket in soup.findAll("table",class_="table"):
    for rank in cricket.findAll("tr",class_="table-body"):
# Out:
# <tr class="table-body rankings-table__hero">
# <td class="table-body__cell table-body__cell--position">1</td>
# <td class="table-body__cell rankings-table__team u-text-left">
# <span class="flag-15 table-body_logo IND u-show-phablet u-hide-mobile"></span>
# <span class="flag-30 table-body_logo IND u-hide-phablet"></span>
#                         India
#                     </td>
# <td class="table-body__cell">29</td>
# <td class="table-body__cell">3,634</td>
# <td class="table-body__cell u-text-right rating">125</td>
# </tr>
# <tr class="table-body">
# <td class="table-body__cell table-body__cell--position">2</td>
# <td class="table-body__cell rankings-table__team u-text-left">
# <span class="flag-15 table-body_logo SA u-hide-mobile"></span>
#                         South Africa
#                     </td>
# <td class="table-body__cell">32</td>
# <td class="table-body__cell">3,589</td>
# <td class="table-body__cell u-text-right rating">112</td>
# </tr>
# <tr class="table-body">
# ...
